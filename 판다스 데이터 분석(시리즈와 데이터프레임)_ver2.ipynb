# %% [markdown]
# # 판다스 데이터 분석
# 판다스는 Python 언어로 작성된 데이터 조작 및 분석 라이브러리입니다. 주요 데이터 구조로 데이터프레임(DataFrame)과 시리즈(Series)를 제공하며, 누락된 데이터 처리, 데이터 병합, 재색인 등 다양한 데이터 처리 기능을 지원합니다. 다양한 데이터 형식(CSV, 엑셀, SQL 데이터베이스 등)을 읽고 쓸 수 있습니다.

# %%
import pandas as pd

# %% [markdown]
# ## 데이터 저장 및 불러오기
# 데이터를 불러오고 저장하는 작업은 데이터 분석에서 중요한 단계입니다. 판다스는 다양한 데이터 형식(CSV, Excel, SQL, JSON 등)을 지원하며, 이러한 형식의 데이터를 불러오거나 저장하는데 사용할 수 있는 기능을 제공합니다.

# %% [markdown]
# ## 데이터 프레임 만들기
# 데이터 프레임은 판다스의 핵심 데이터 구조로서, 2차원 레이블이 붙은 데이터를 포함합니다. 각 데이터 프레임은 다양한 데이터 유형 (예: 정수, 실수, 문자열 등)을 포함할 수 있는 하나 이상의 열로 구성됩니다.

# %% [markdown]
# ## 데이터프레임 행, 열 접근하기
# 데이터 프레임에서 특정 열을 선택하는 것은 데이터 분석에서 일반적으로 수행하는 작업입니다.
# ### 단일 열 접근하기
# 열 이름을 사용하여 데이터 프레임에서 단일 열을 선택할 수 있습니다.

# %%
data = {
    'name': ['John', 'Anna', 'Peter', 'Linda'],
    'age': [28, 24, 35, 32],
    'city': ['New York', 'Paris', 'Berlin', 'London']
}

df = pd.DataFrame(data)
df
# Out:
#     name  age      city
# 0   John   28  New York
# 1   Anna   24     Paris
# 2  Peter   35    Berlin
# 3  Linda   32    London

# %% [markdown]
# ### 여러 열 접근하기
# 여러 열을 선택하려면, 열 이름의 리스트를 사용하면 됩니다.

# %% [markdown]
# ### 시리즈 통계 함수
# * count(): 시리즈에서 NA 값을 제외한 값의 수를 반환합니다.

# %% [markdown]
# * sum(): 시리즈의 합을 반환합니다.

# %% [markdown]
# * mean(): 시리즈의 평균을 반환합니다.

# %% [markdown]
# * median(): 시리즈의 중간값을 반환합니다.

# %% [markdown]
# * mode(): 시리즈의 최빈값을 반환합니다.

# %% [markdown]
# * std(): 시리즈의 표준편차를 반환합니다.

# %% [markdown]
# * min(), max(): 시리즈의 최소값, 최대값을 반환합니다.

# %% [markdown]
# * abs(): 시리즈의 각 요소의 절대값을 반환합니다.

# %% [markdown]
# * prod(): 시리즈의 값들의 곱을 반환합니다.

# %% [markdown]
# * var(): 시리즈의 분산을 반환합니다.

# %% [markdown]
# * describe(): 시리즈의 기술통계(평균, 표준편차, 최소값, 25%, 50%, 75% 백분위수, 최대값)를 반환합니다.

# %% [markdown]
# * quantile(q): 시리즈의 분위수를 계산합니다. q는 0과 1 사이의 분위수를 지정합니다.

# %% [markdown]
# * cumsum(): 시리즈의 누적 합계를 계산합니다.

# %% [markdown]
# * cumprod(): 시리즈의 누적 곱을 계산합니다.

# %% [markdown]
# * pct_change(): 시리즈에서 값 간의 퍼센트 변화를 계산합니다.

# %% [markdown]
# * corr(other), cov(other): 시리즈와 다른 시리즈 간의 상관계수, 공분산을 계산합니다.

# %% [markdown]
# ### 행, 열 접근하기
# 특정 행, 열에 접근하는 방법에는 loc와 iloc가 있습니다.
# * loc는 레이블 기반의 데이터 선택 방법으로, 레이블의 이름을 통해 값을 선택합니다.

# %% [markdown]
# * iloc는 정수 기반의 위치를 기반으로 값을 선택합니다. 즉, 행이나 열의 정수 인덱스를 통해 값을 선택합니다.

# %% [markdown]
# ### 특정 조건의 행 접근하기
# 특정 조건을 만족하는 행을 선택하는 것은 pandas에서 자주 사용되는 테크닉입니다. 이를 수행하는 기본적인 방법은 불리언 인덱싱(Boolean Indexing)을 사용하는 것입니다. 이는 데이터프레임에 조건을 적용하여 True 또는 False로 구성된 불리언 시리즈를 생성하고, 이를 사용하여 True에 해당하는 행만 선택하는 방법입니다.
#
# * 불리언 인덱싱으로 특정 조건의 행 접근하기

# %% [markdown]
# * 쿼리문을 사용하여 특정 조건의 행 접근하기

# %% [markdown]
# * isin() 함수를 활용하여 특정 값을 포함하는 행 접근하기

# %% [markdown]
# * .str.contains() 함수를 활용하여 특정 값이 포함된 행 접근하기

# %% [markdown]
# ### 연습문제
# ```student.csv``` 파일을 불러와서 아래 문제들을 해결하세요.
# 1. 0번째 열을 선택하세요.

# %%
import pandas as pd

df = pd.read_csv("data/student.csv")
df.iloc[:, 0]
# Out:
# 0     yllyn
# 1     gcvkk
# 2     pstei
# 3     hrbmo
# 4     nspni
#       ...
# 95    siedz
# 96    vrtke
# 97    lygeb
# 98    xvrsw
# 99    qcbis
# Name: Name, Length: 100, dtype: object

# %% [markdown]
# 2. 'Name'과 'Score' 열을 선택하세요.

# %%
df[["Name", 'Score']]
# Out:
#      Name  Score
# 0   yllyn     99
# 1   gcvkk     69
# 2   pstei     64
# 3   hrbmo     71
# 4   nspni     56
# ..    ...    ...
# 95  siedz     53
# 96  vrtke     99
# 97  lygeb     79
# 98  xvrsw     62
# 99  qcbis     84
#
# [100 rows x 2 columns]

# %% [markdown]
# 3. 'Age' 열의 평균을 계산하세요.

# %%
df['Age'].mean()
# Out:
# 16.49

# %% [markdown]
# 4. 'Score' 열의 최댓값과 최솟값을 찾으세요.

# %%
df['Score'].max(), df['Score'].min()
# Out:
# (100, 50)

# %% [markdown]
# 5. 0번째 행을 선택하세요.

# %%
df.iloc[[0]]
# Out:
#     Name  Age Gender  Score
# 0  yllyn   16   Male     99

# %% [markdown]
# 6. 마지막 행을 선택하세요.

# %%
df.iloc[[-1]]
# Out:
#      Name  Age Gender  Score
# 99  qcbis   18   Male     84

# %% [markdown]
# 7. 짝수인 행을 선택하세요.

# %%
df.iloc[::2]
# Out:
#      Name  Age  Gender  Score
# 0   yllyn   16    Male     99
# 2   pstei   18  Female     64
# 4   nspni   15  Female     56
# 6   wqxah   16  Female     80
# 8   shxsw   16  Female     65
# 10  mtaji   18  Female     84
# 12  egopt   16  Female     52
# 14  mogyd   16  Female     63
# 16  hvkbx   17  Female     93
# 18  vheom   16  Female    100
# 20  lmdfg   17    Male     73
# 22  tglss   16    Male     50
# 24  jvgmq   17    Male     65
# 26  cytfe   17  Female     58
# 28  vzcmm   16    Male     58
# 30  armhe   15  Female     88
# 32  hkyuv   18    Male     55
# 34  tqkai   17    Male     54
# 36  kiapt   17    Male     99
# 38  pjure   16  Female     88
# 40  vxmqu   15    Male     71
# 42  nbogc   15    Male     79
# 44  syfik   16  Female     78
# 46  qkrdo   18    Male     63
# 48  ihppc   18    Male     98
# 50  bivau   16    Male     60
# 52  nhdtd   18    Male     74
# 54  xbudk   17    Male     86
# 56  usjvd   17    Male     76
# 58  mpvkj   15    Male     54
# 60  rbvrq   16    Male     72
# 62  eqkda   17  Female     82
# 64  uftke   18    Male     94
# 66  wasdn   16    Male     91
# 68  xtclr   17    Male     62
# 70  mbvkt   16    Male     94
# 72  jptnn   17    Male    100
# 74  xzmgi   17  Female     84
# 76  ghikl   18    Male     63
# 78  hppuv   18    Male     51
# 80  twamd   16    Male     75
# 82  nwbow   18    Male     90
# 84  rlavb   18    Male     80
# 86  phpiz   18    Male     95
# 88  fnbbu   18  Female     87
# 90  ljmgd   18    Male     63
# 92  gtifa   15    Male     98
# 94  tpytc   16  Female     88
# 96  vrtke   17    Male     99
# 98  xvrsw   15  Female     62

# %% [markdown]
# 8. 2번째 행의 'Score'를 찾으세요.

# %%
df.loc[2, 'Score']
# Out:
# 64

# %% [markdown]
# 9. 'Gender' 열이 'Male'인 모든 행을 선택하세요.

# %%
df[df['Gender'] == 'Male']
# Out:
#      Name  Age Gender  Score
# 0   yllyn   16   Male     99
# 3   hrbmo   18   Male     71
# 7   nrvkk   16   Male     96
# 19  kanvi   15   Male     60
# 20  lmdfg   17   Male     73
# 22  tglss   16   Male     50
# 24  jvgmq   17   Male     65
# 25  jfvaf   15   Male     80
# 27  rkldg   16   Male     95
# 28  vzcmm   16   Male     58
# 29  nrmrr   17   Male     58
# 32  hkyuv   18   Male     55
# 34  tqkai   17   Male     54
# 35  cssyi   16   Male     81
# 36  kiapt   17   Male     99
# 39  cuagq   16   Male     60
# 40  vxmqu   15   Male     71
# 41  vuihd   15   Male     80
# 42  nbogc   15   Male     79
# 45  idepp   16   Male     95
# 46  qkrdo   18   Male     63
# 48  ihppc   18   Male     98
# 49  ebxxi   17   Male     56
# 50  bivau   16   Male     60
# 52  nhdtd   18   Male     74
# 53  edkyd   15   Male     81
# 54  xbudk   17   Male     86
# 56  usjvd   17   Male     76
# 57  bhgjm   17   Male     64
# 58  mpvkj   15   Male     54
# 59  rlcwc   15   Male     59
# 60  rbvrq   16   Male     72
# 64  uftke   18   Male     94
# 66  wasdn   16   Male     91
# 67  dustm   16   Male     61
# 68  xtclr   17   Male     62
# 70  mbvkt   16   Male     94
# 71  gfaqq   17   Male     88
# 72  jptnn   17   Male    100
# 73  wxojq   17   Male     78
# 75  rdrhp   18   Male     75
# 76  ghikl   18   Male     63
# 77  ofkvw   16   Male     70
# 78  hppuv   18   Male     51
# 80  twamd   16   Male     75
# 81  rqlka   18   Male     87
# 82  nwbow   18   Male     90
# 83  ieomy   15   Male     68
# 84  rlavb   18   Male     80
# 86  phpiz   18   Male     95
# 87  ctfvy   16   Male     95
# 89  kjcjw   18   Male     60
# 90  ljmgd   18   Male     63
# 92  gtifa   15   Male     98
# 96  vrtke   17   Male     99
# 97  lygeb   15   Male     79
# 99  qcbis   18   Male     84

# %% [markdown]
# 10. 'Score' 열이 평균 점수보다 높은 모든 행을 선택하세요.

# %%
df[df['Score'] > df['Score'].mean()]
# Out:
#      Name  Age  Gender  Score
# 0   yllyn   16    Male     99
# 5   fchpf   16  Female     79
# 6   wqxah   16  Female     80
# 7   nrvkk   16    Male     96
# 9   mhkcq   15  Female     90
# 10  mtaji   18  Female     84
# 11  nijyv   15  Female     77
# 13  hhtwc   17  Female     80
# 15  sptrj   17  Female     88
# 16  hvkbx   17  Female     93
# 18  vheom   16  Female    100
# 21  hhlwu   17  Female     98
# 23  obnsg   16  Female     82
# 25  jfvaf   15    Male     80
# 27  rkldg   16    Male     95
# 30  armhe   15  Female     88
# 33  hkmmk   18  Female     82
# 35  cssyi   16    Male     81
# 36  kiapt   17    Male     99
# 38  pjure   16  Female     88
# 41  vuihd   15    Male     80
# 42  nbogc   15    Male     79
# 43  svzpn   15  Female     84
# 44  syfik   16  Female     78
# 45  idepp   16    Male     95
# 47  skenz   16  Female     79
# 48  ihppc   18    Male     98
# 51  nqnzo   18  Female     94
# 53  edkyd   15    Male     81
# 54  xbudk   17    Male     86
# 55  mkfjm   16  Female     97
# 62  eqkda   17  Female     82
# 63  jhvke   16  Female     87
# 64  uftke   18    Male     94
# 66  wasdn   16    Male     91
# 70  mbvkt   16    Male     94
# 71  gfaqq   17    Male     88
# 72  jptnn   17    Male    100
# 73  wxojq   17    Male     78
# 74  xzmgi   17  Female     84
# 79  wbrvy   16  Female     79
# 81  rqlka   18    Male     87
# 82  nwbow   18    Male     90
# 84  rlavb   18    Male     80
# 85  ivibx   17  Female    100
# 86  phpiz   18    Male     95
# 87  ctfvy   16    Male     95
# 88  fnbbu   18  Female     87
# 92  gtifa   15    Male     98
# 93  xbgje   15  Female     97
# 94  tpytc   16  Female     88
# 96  vrtke   17    Male     99
# 97  lygeb   15    Male     79
# 99  qcbis   18    Male     84

# %% [markdown]
# 11. 'Gender'가 'Female'이고, 'Age'가 18인 모든 행을 선택하세요.

# %%
df[(df['Gender'] == 'Female') & (df['Age'] == 18)]
# Out:
#      Name  Age  Gender  Score
# 2   pstei   18  Female     64
# 10  mtaji   18  Female     84
# 33  hkmmk   18  Female     82
# 51  nqnzo   18  Female     94
# 88  fnbbu   18  Female     87

# %% [markdown]
# 12. 'Score'가 70 이상인 학생들의 평균 'Age'를 계산하세요.

# %%
df[df['Score'] >= 70]['Age'].mean()
# Out:
# 16.476923076923075

# %% [markdown]
# 13. 'Age'가 17 이상이고 'Score'가 80 이상인 모든 행을 선택하세요.

# %%
df[(df['Age'] >= 17) & (df['Score'] >= 80)]
# Out:
#      Name  Age  Gender  Score
# 10  mtaji   18  Female     84
# 13  hhtwc   17  Female     80
# 15  sptrj   17  Female     88
# 16  hvkbx   17  Female     93
# 21  hhlwu   17  Female     98
# 33  hkmmk   18  Female     82
# 36  kiapt   17    Male     99
# 48  ihppc   18    Male     98
# 51  nqnzo   18  Female     94
# 54  xbudk   17    Male     86
# 62  eqkda   17  Female     82
# 64  uftke   18    Male     94
# 71  gfaqq   17    Male     88
# 72  jptnn   17    Male    100
# 74  xzmgi   17  Female     84
# 81  rqlka   18    Male     87
# 82  nwbow   18    Male     90
# 84  rlavb   18    Male     80
# 85  ivibx   17  Female    100
# 86  phpiz   18    Male     95
# 88  fnbbu   18  Female     87
# 96  vrtke   17    Male     99
# 99  qcbis   18    Male     84

# %% [markdown]
# 14. 'Score'의 값이 'Score'의 중간값과 같은 모든 행을 선택하세요.

# %%
df[df['Score'] == df['Score'].median()]
# Out:
#      Name  Age  Gender  Score
# 5   fchpf   16  Female     79
# 42  nbogc   15    Male     79
# 47  skenz   16  Female     79
# 79  wbrvy   16  Female     79
# 97  lygeb   15    Male     79

# %% [markdown]
# 15. 'Score'가 90 이상인 학생 중에서 'Age'가 가장 어린 학생의 이름을 찾으세요.

# %%
a = df[df['Score'] >= 90]['Age'].min()
df[(df['Age'] == a) & (df['Score'] >= 90)]
# Out:
#      Name  Age  Gender  Score
# 9   mhkcq   15  Female     90
# 92  gtifa   15    Male     98
# 93  xbgje   15  Female     97
